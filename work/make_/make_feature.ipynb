# %%
import pandas as pd

# %%
# '商品名' S貼りと逆S貼りの区別
def label_product(x):
    if isinstance(x, str) and '逆S貼' in x:
        return '逆S'
    else:
        return x

# %%
#データ読み込み，結果保存用のdfを定義
df = pd.read_excel('./data/raw/購買データ_商品属性付き.xlsx')
df['商品名'] = df['商品名'].apply(label_product)
result_df = pd.DataFrame()
result_df = df[['得意先コード']]

# %%
# 大分類
result_df['封筒'] = df['サイズ・規格'].apply(lambda x: 1 if '封筒' in x else 0)
result_df['袋'] = df['サイズ・規格'].apply(lambda x: 1 if '袋' in x else 0)
result_df['ハガキ'] = df['サイズ・規格'].apply(lambda x: 1 if 'ハガキ' in x else 0)

# 角 or 長？

# 中分類？小分類？
result_df['角0'] = df['商品名'].apply(lambda x: 1 if '角０' in x else 0)
result_df['角1'] = df['商品名'].apply(lambda x: 1 if '角１' in x else 0)
result_df['角2'] = df['商品名'].apply(lambda x: 1 if '角２' in x else 0)
result_df['角3'] = df['商品名'].apply(lambda x: 1 if '角３' in x else 0)
result_df['角4'] = df['商品名'].apply(lambda x: 1 if '角４' in x else 0)
result_df['角5'] = df['商品名'].apply(lambda x: 1 if '角５' in x else 0)
result_df['角6'] = df['商品名'].apply(lambda x: 1 if '角６' in x else 0)
result_df['角7'] = df['商品名'].apply(lambda x: 1 if '角７' in x else 0)
result_df['角8'] = df['商品名'].apply(lambda x: 1 if '角８' in x else 0)

result_df['長1'] = df['商品名'].apply(lambda x: 1 if '長１' in x else 0)
result_df['長2'] = df['商品名'].apply(lambda x: 1 if '長２' in x else 0)
result_df['長3'] = df['商品名'].apply(lambda x: 1 if '長３' in x else 0)
result_df['長4'] = df['商品名'].apply(lambda x: 1 if '長４' in x else 0)

# 貼り方？
result_df['S貼'] = df['商品名'].apply(lambda x: 1 if 'Ｓ貼' in x else 0)
result_df['C貼'] = df['商品名'].apply(lambda x: 1 if 'Ｃ貼' in x else 0)
result_df['逆S'] = df['商品名'].apply(lambda x: 1 if '逆Ｓ貼' in x else 0) #逆S貼
result_df['かます'] = df['商品名'].apply(lambda x: 1 if 'かます' in x else 0)

#オーダメイド or 既製品？
# Out:
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['封筒'] = df['サイズ・規格'].apply(lambda x: 1 if '封筒' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['袋'] = df['サイズ・規格'].apply(lambda x: 1 if '袋' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['ハガキ'] = df['サイズ・規格'].apply(lambda x: 1 if 'ハガキ' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角0'] = df['商品名'].apply(lambda x: 1 if '角０' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角1'] = df['商品名'].apply(lambda x: 1 if '角１' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角2'] = df['商品名'].apply(lambda x: 1 if '角２' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角3'] = df['商品名'].apply(lambda x: 1 if '角３' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角4'] = df['商品名'].apply(lambda x: 1 if '角４' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角5'] = df['商品名'].apply(lambda x: 1 if '角５' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角6'] = df['商品名'].apply(lambda x: 1 if '角６' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角7'] = df['商品名'].apply(lambda x: 1 if '角７' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['角8'] = df['商品名'].apply(lambda x: 1 if '角８' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['長1'] = df['商品名'].apply(lambda x: 1 if '長１' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['長2'] = df['商品名'].apply(lambda x: 1 if '長２' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['長3'] = df['商品名'].apply(lambda x: 1 if '長３' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['長4'] = df['商品名'].apply(lambda x: 1 if '長４' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['S貼'] = df['商品名'].apply(lambda x: 1 if 'Ｓ貼' in x else 0)
# /var/folders/sk/06xv0jv50lnbxl4_w0w6g9980000gn/T/ipykernel_9619/3260988982.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['C貼'] = df['商品名'].apply(lambda x: 1 if 'Ｃ貼' in x else 0)

# %%
# 顧客ごとに統合
result_df = result_df.groupby('得意先コード').max().reset_index()
result_df.to_csv('./data/feature/feature.csv', index=False, encoding='utf-8')
